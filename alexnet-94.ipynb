# %%
import os
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

# Dataset Path
DATA_PATH = "/kaggle/input/preprocess-dataset-augmentation/AD_AUG"

# Function to load data paths and labels
def load_data(data_path):
    all_paths = glob.glob(f'{data_path}/**/*.*', recursive=True)
    labels = [os.path.split(os.path.split(path)[0])[1] for path in all_paths]
    return pd.DataFrame({'Filepath': all_paths, 'Target': labels}).sample(frac=1).reset_index(drop=True)

dataframe = load_data(DATA_PATH)

# Function to visualize the dataset distribution
def explore_data(df):
    print("Dataset shape:", df.shape)
    plt.figure(figsize=(8, 5))
    sns.countplot(data=df, x='Target')
    plt.title("Class Distribution")
    plt.show()

explore_data(dataframe)

# Preprocessing and Data Augmentation
def preprocess_and_augment_data(df):
    datagen = ImageDataGenerator(
        rescale=1.0 / 255,  # Normalize pixel values
        rotation_range=15,  # Random rotation
        width_shift_range=0.1,  # Horizontal shift
        height_shift_range=0.1,  # Vertical shift
        zoom_range=0.2,  # Zoom in/out
        horizontal_flip=True,  # Flip images horizontally
        validation_split=0.2  # Split for training/validation
    )

    train_data = datagen.flow_from_dataframe(
        df, x_col='Filepath', y_col='Target', target_size=(128, 128), batch_size=32,
        subset='training', class_mode='categorical', shuffle=True
    )

    val_data = datagen.flow_from_dataframe(
        df, x_col='Filepath', y_col='Target', target_size=(128, 128), batch_size=32,
        subset='validation', class_mode='categorical', shuffle=False
    )

    return train_data, val_data

train_data, val_data = preprocess_and_augment_data(dataframe)

# Build the AlexNet Model
def build_alexnet(input_shape, num_classes):
    model = models.Sequential()

    # Layer 1
    model.add(layers.Conv2D(96, (11, 11), strides=(4, 4), activation='relu', input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

    # Layer 2
    model.add(layers.Conv2D(256, (5, 5), activation='relu', padding='same'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

    # Layer 3
    model.add(layers.Conv2D(384, (3, 3), activation='relu', padding='same'))
    model.add(layers.Conv2D(384, (3, 3), activation='relu', padding='same'))
    model.add(layers.Conv2D(256, (3, 3), activation='relu', padding='same'))
    model.add(layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2)))

    # Flatten and Fully Connected Layers
    model.add(layers.Flatten())
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(num_classes, activation='softmax'))

    # Compile the model
    model.compile(optimizer=optimizers.Adam(learning_rate=0.0001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Define input shape and number of classes
input_shape = (128, 128, 3)
num_classes = len(dataframe['Target'].unique())

# Build the model
model = build_alexnet(input_shape, num_classes)

# Model Summary
model.summary()

# Train the Model
history = model.fit(train_data, epochs=30, validation_data=val_data)

# Evaluate the Model
loss, accuracy = model.evaluate(val_data)
print(f"Validation Accuracy: {accuracy * 100:.2f}%")

# Plot Training and Validation Accuracy/Loss
def plot_training_history(history):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# Classification Report and Confusion Matrix
y_true = val_data.classes
y_pred = np.argmax(model.predict(val_data), axis=-1)

print("Classification Report:")
print(classification_report(y_true, y_pred, target_names=val_data.class_indices.keys()))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=val_data.class_indices.keys(),
            yticklabels=val_data.class_indices.keys())
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Dataset shape: (12020, 2)
# Found 9616 validated image filenames belonging to 4 classes.
# Found 2404 validated image filenames belonging to 4 classes.
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)                   │ (None, 30, 30, 96)          │          34,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 30, 30, 96)          │             384 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 14, 14, 96)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 14, 14, 256)         │         614,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 14, 14, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 6, 6, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 6, 6, 384)           │         885,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_23 (Conv2D)                   │ (None, 6, 6, 384)           │       1,327,488 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_24 (Conv2D)                   │ (None, 6, 6, 256)           │         884,992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 2, 2, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 4096)                │       4,198,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 4096)                │      16,781,312 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 4)                   │          16,388 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,744,708 (94.39 MB)
#  Trainable params: 24,744,004 (94.39 MB)
#  Non-trainable params: 704 (2.75 KB)
# Epoch 1/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 61s 184ms/step - accuracy: 0.3629 - loss: 1.2867 - val_accuracy: 0.2733 - val_loss: 2.1013
# Epoch 2/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - accuracy: 0.6151 - loss: 0.8649 - val_accuracy: 0.6610 - val_loss: 0.7706
# Epoch 3/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 169ms/step - accuracy: 0.7391 - loss: 0.6128 - val_accuracy: 0.7325 - val_loss: 0.6342
# Epoch 4/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - accuracy: 0.8083 - loss: 0.4648 - val_accuracy: 0.8103 - val_loss: 0.4621
# Epoch 5/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 51s 168ms/step - accuracy: 0.8551 - loss: 0.3613 - val_accuracy: 0.8091 - val_loss: 0.4571
# Epoch 6/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 51s 167ms/step - accuracy: 0.8756 - loss: 0.3019 - val_accuracy: 0.8232 - val_loss: 0.4231
# Epoch 7/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 51s 167ms/step - accuracy: 0.8812 - loss: 0.2871 - val_accuracy: 0.8948 - val_loss: 0.2768
# Epoch 8/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 51s 167ms/step - accuracy: 0.9003 - loss: 0.2526 - val_accuracy: 0.8494 - val_loss: 0.4118
# Epoch 9/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 56s 182ms/step - accuracy: 0.9031 - loss: 0.2404 - val_accuracy: 0.8973 - val_loss: 0.2752
# Epoch 10/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 171ms/step - accuracy: 0.9126 - loss: 0.2229 - val_accuracy: 0.8881 - val_loss: 0.2760
# Epoch 11/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 169ms/step - accuracy: 0.9270 - loss: 0.1774 - val_accuracy: 0.8827 - val_loss: 0.3042
# Epoch 12/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 171ms/step - accuracy: 0.9320 - loss: 0.1795 - val_accuracy: 0.9176 - val_loss: 0.1991
# Epoch 13/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 171ms/step - accuracy: 0.9340 - loss: 0.1679 - val_accuracy: 0.9343 - val_loss: 0.1721
# Epoch 14/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - accuracy: 0.9355 - loss: 0.1692 - val_accuracy: 0.7858 - val_loss: 0.6522
# Epoch 15/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 169ms/step - accuracy: 0.9389 - loss: 0.1587 - val_accuracy: 0.9027 - val_loss: 0.2491
# Epoch 16/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - accuracy: 0.9497 - loss: 0.1318 - val_accuracy: 0.7812 - val_loss: 0.6820
# Epoch 17/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - accuracy: 0.9373 - loss: 0.1636 - val_accuracy: 0.9359 - val_loss: 0.1599
# Epoch 18/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 171ms/step - accuracy: 0.9522 - loss: 0.1286 - val_accuracy: 0.9501 - val_loss: 0.1253
# Epoch 19/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - accuracy: 0.9532 - loss: 0.1213 - val_accuracy: 0.9455 - val_loss: 0.1481
# Epoch 20/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 53s 172ms/step - accuracy: 0.9486 - loss: 0.1320 - val_accuracy: 0.9547 - val_loss: 0.1161
# Epoch 21/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 169ms/step - accuracy: 0.9570 - loss: 0.1192 - val_accuracy: 0.9368 - val_loss: 0.1921
# Epoch 22/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 169ms/step - accuracy: 0.9549 - loss: 0.1270 - val_accuracy: 0.9314 - val_loss: 0.2048
# Epoch 23/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 169ms/step - accuracy: 0.9589 - loss: 0.1133 - val_accuracy: 0.9397 - val_loss: 0.1726
# Epoch 24/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - accuracy: 0.9610 - loss: 0.1042 - val_accuracy: 0.8993 - val_loss: 0.3002
# Epoch 25/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 53s 172ms/step - accuracy: 0.9616 - loss: 0.1017 - val_accuracy: 0.9463 - val_loss: 0.1444
# Epoch 26/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - accuracy: 0.9588 - loss: 0.1058 - val_accuracy: 0.9334 - val_loss: 0.1751
# Epoch 27/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 171ms/step - accuracy: 0.9624 - loss: 0.1002 - val_accuracy: 0.8952 - val_loss: 0.3094
# Epoch 28/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 171ms/step - accuracy: 0.9687 - loss: 0.0867 - val_accuracy: 0.9035 - val_loss: 0.2693
# Epoch 29/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 169ms/step - accuracy: 0.9606 - loss: 0.1017 - val_accuracy: 0.8873 - val_loss: 0.2968
# Epoch 30/30
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 52s 170ms/step - accuracy: 0.9647 - loss: 0.0903 - val_accuracy: 0.9468 - val_loss: 0.1310
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.9402 - loss: 0.1503
# Validation Accuracy: 94.01%
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step
# Classification Report:
#                     precision    recall  f1-score   support
#
#      Mild_Demented       0.91      0.93      0.92       590
#  Moderate_Demented       1.00      0.99      0.99       604
#       Non_Demented       0.99      0.90      0.94       591
# Very_Mild_Demented       0.90      0.96      0.93       619
#
#           accuracy                           0.95      2404
#          macro avg       0.95      0.95      0.95      2404
#       weighted avg       0.95      0.95      0.95      2404
